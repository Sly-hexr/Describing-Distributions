# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('C:\\Users\\Sly\\Downloads\\medi_data.csv')

# %%
df.head(3)
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
#
#    Reflux_esophagitis Asthma     Services  Initial_days  TotalCharge  \
# 0                   0      1   Blood Work     10.585770  3726.702860
# 1                   1      0  Intravenous     15.129562  4193.190458
# 2                   0      0   Blood Work      4.772177  2434.234222
#
#    Additional_charges
# 0         17939.40342
# 1         17612.99812
# ...

# %% [markdown]
# ### We will add a green line for the median. We will also change it to a dashed line by adding a "linestyle," ls = '--'

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# #### Is it Discrete or Continuous? Does it have a skew? If so, which direction (+/-)

# %% [markdown]
# This is a discreet distribution with no skew

# %% [markdown]
# #### Using the Pearson calculation, calculate the kurtosis
#
# Mesokurtic (Kurtosis ~3)
#
# Leptokurtic (Kurtosis >3)
#
# Platykurtic (Kurtosis < 3)

# %%
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)

kurt
# Out:
# 3.013147515833447

# %% [markdown]
# VitD_levels are Mesokurtic

# %%
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# This is a discreet distribution with no skew

# %%
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)

kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# Doc_visits displays mesokurtosis

# %%
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# This is a continuous distribution with a positive skew

# %%
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)

kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# TotalCharge displays Leptokurtosis
